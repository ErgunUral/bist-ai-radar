# %% [markdown]
# # BIST AI Radar V8
# Temel analiz + AI skor + Google Sheets dashboard

# %%
# !pip install -r ../requirements.txt

# %%
from src.period_manager import latest_period
from src.ratios import calculate_ratios, FinancialInputs
from src.scoring import calculate_score
from src.ai_decision import decision_from_score

print('BIST AI Radar V8 hazır')
